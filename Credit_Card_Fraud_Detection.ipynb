# %%
#  DataSet Download Link 
#  --->  https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv('creditcard.csv')
ds.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
ds.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
ds.Class.describe()
# Out:
# count    284807.000000
# mean          0.001727
# std           0.041527
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Class, dtype: float64

# %%
ds.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
ds['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
valid = ds[ds.Class == 0]
fraud = ds[ds.Class == 1]
print(valid.shape)
fraud.shape
# Out:
# (284315, 31)
# (492, 31)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
ds.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
new=pd.concat([s_valid,fraud],axis=0)
new.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 90419    63012.0  1.191624  0.191115  0.644114  0.918406 -0.375981 -0.250496
# 220112  142029.0  2.032646 -1.075618 -0.784795 -0.737940 -1.006292 -0.863150
# 107691   70563.0 -0.677664 -0.483585  1.895252 -1.780627 -0.942811  0.198937
# 89897    62776.0 -1.280216  1.164430  1.922740  0.438169 -0.102793 -0.041219
# 50859    44679.0 -0.881313  0.906811  1.364896 -0.381389  0.317243  1.372148
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 90419  -0.216834  0.085267  0.013016  ... -0.166718 -0.539867  0.064033
# 220112 -0.632289 -0.252331 -0.123771  ...  0.253792  0.668322  0.102011
# 107691 -0.025048  0.259071 -1.206951  ...  0.652415  1.525034  0.115389
# 89897   0.388088  0.550736 -1.291878  ...  0.256809  0.450817 -0.195947
# 50859   2.609370 -0.857617 -0.047021  ... -0.285917 -0.178665 -0.577266
#
# ...

# %%
new.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new['Class'].value_counts()
# Out:
# 0    5000
# 1     492
# Name: Class, dtype: int64

# %%
new.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94488.019000  0.028958 -0.055675  0.029525 -0.041648 -0.013987
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.009127  0.014822  0.012914 -0.003980  ... -0.003312 -0.014949
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.016965  0.009308 -0.001324 -0.005319 -0.007291 -0.002844 -0.001617
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       90.778792
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
ds.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
x= new.drop(columns='Class',axis=1)
y= new['Class']
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 90419    63012.0  1.191624  0.191115  0.644114  0.918406 -0.375981 -0.250496
# 220112  142029.0  2.032646 -1.075618 -0.784795 -0.737940 -1.006292 -0.863150
# 107691   70563.0 -0.677664 -0.483585  1.895252 -1.780627 -0.942811  0.198937
# 89897    62776.0 -1.280216  1.164430  1.922740  0.438169 -0.102793 -0.041219
# 50859    44679.0 -0.881313  0.906811  1.364896 -0.381389  0.317243  1.372148
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 90419     0
# 220112    0
# 107691    0
# 89897     0
# 50859     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 5492, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=4)
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_train)
accuracy_score_of_pred=accuracy_score(y_pred,y_train)
accuracy_score_of_pred
# Out:
# 0.9801957659913498

# %%
from sklearn.metrics import classification_report
classification_report(y_pred,y_train)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.99      0.99      4022\n           1       0.86      0.91      0.89       371\n\n    accuracy                           0.98      4393\n   macro avg       0.93      0.95      0.94      4393\nweighted avg       0.98      0.98      0.98      4393\n'

# %%
y_test_pred=model.predict(x_test)
accuracy_score_of_test_pred=accuracy_score(y_test_pred,y_test)
accuracy_score_of_test_pred
# Out:
# 0.9808917197452229

# %%
classification_report(y_test_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.99      0.99       998\n           1       0.91      0.88      0.89       101\n\n    accuracy                           0.98      1099\n   macro avg       0.95      0.94      0.94      1099\nweighted avg       0.98      0.98      0.98      1099\n'

# %%
X=ds.drop(columns='Class',axis=1)
Y=ds['Class']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=4)
Y_pred=model.predict(X_train)
accuracy_score_of_Y_pred=accuracy_score(Y_pred,Y_train)
accuracy_score_of_Y_pred
# Out:
# 0.9910158221598017

# %%
classification_report(Y_pred,Y_train)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      1.00      1.00    225519\n           1       0.86      0.14      0.25      2326\n\n    accuracy                           0.99    227845\n   macro avg       0.92      0.57      0.62    227845\nweighted avg       0.99      0.99      0.99    227845\n'

# %%
Y_test_pred=model.predict(X_test)
accuracy_score_of_Y_test_pred=accuracy_score(Y_test_pred,Y_test)
accuracy_score_of_Y_test_pred
# Out:
# 0.9917137740950107

# %%
classification_report(Y_test_pred,Y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      1.00      1.00     56405\n           1       0.92      0.17      0.28       557\n\n    accuracy                           0.99     56962\n   macro avg       0.96      0.58      0.64     56962\nweighted avg       0.99      0.99      0.99     56962\n'
